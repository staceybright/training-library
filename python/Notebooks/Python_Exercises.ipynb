# %% [markdown]
# ## Exercise #1
# *Create a dictionary with strings as keys.*

# %%
product_dict = {}
product_dict['Speaker1'] = {'Color':'Black', 'Size':'Medium', 'Shape':'Oval', 'Material':'Hybrid','Weight':'3.2'}
product_dict['Speaker2'] = {'Color':'Blue', 'Size':'Medium', 'Shape':'Oval', 'Material':'Hybrid','Weight':'3.2'}
product_dict['Speaker3'] = {'Color':'Red', 'Size':'Medium', 'Shape':'Oval', 'Material':'Hybrid','Weight':'3.2'}
product_dict['Speaker4'] = {'Color':'Black', 'Size':'Large', 'Shape':'Rectangular', 'Material':'Hybrid','Weight':'3.2'}
product_dict['Speaker5'] = {'Color':'Blue', 'Size':'Large', 'Shape':'Rectangular', 'Material':'Hybrid','Weight':'3.2'}
product_dict['Speaker6'] = {'Color':'Red', 'Size':'Large', 'Shape':'Rectangular', 'Material':'Hybrid','Weight':'3.2'}

# %% [markdown]
# ## Exercise #2
# Print out your own creative statement.

# %%
print 'I bought {} {} speakers at wholesale pricing, but was ripped off by ${:.2f}!'\
      .format(10, 'blue', 150.0)
# Out:
# I bought 10 blue speakers at wholesale pricing, but was ripped off by $150.00!

# %% [markdown]
# ## Exercise #3
# Type help() and explore the options.

# %%
# Executing help() without options begins a general help session. Explore, and type 'q' to quit...
help()
# Out:
# Welcome to Python 2.7!  This is the online help utility.
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at http://docs.python.org/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, or topics, type "modules",
# "keywords", or "topics".  Each module also comes with a one-line summary
# of what it does; to list the modules whose summaries contain a given word
# such as "spam", type "modules spam".
# help> modules
# Please wait a moment while I gather a list of all available modules...
#
# The following tasks in the stwcs.gui package can be run with TEAL:
#      apply_headerlet          archive_headerlet          attach_headerlet
#      delete_headerlet         extract_headerlet         headerlet_summary
# ...

# %% [markdown]
# ## Exercise #4
# Create a vector with 10 values equal to the square of the index.

# %%
a = range(10)
b = [x**2 for x in a]
print b
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ## Exercise #5
# Create the following sequence using a for statement: 2001-01-01, 2001-02-01, 2001-03-01, 2001-04-01.

# %%
a = range(1,5)
for x in a: print '2001-0{}-01'.format(x)
# Out:
# 2001-01-01
# 2001-02-01
# 2001-03-01
# 2001-04-01

# %% [markdown]
# ## Exercise #6
